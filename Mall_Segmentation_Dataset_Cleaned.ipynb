# %% [markdown]
# #**Task 1 - Data Cleaning and Preprocessing**

# %% [markdown]
# ###*Import Libraries*

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ###*Read and View Dataset*

# %%
df = pd.read_csv('Mall_Customers.csv')

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# ###*Check and fix data types (e.g., age should be int, date as datetime).*

# %%
df.dtypes
# Out:
# CustomerID                 int64
# Gender                    object
# Age                        int64
# Annual Income (k$)         int64
# Spending Score (1-100)     int64
# dtype: object

# %% [markdown]
# **All of the attributes have correct datatypes.**

# %% [markdown]
# ###*Identify and handle missing values using .isnull()*

# %%
mv = df.isnull().sum()

# %%
mv
# Out:
# CustomerID                0
# Gender                    0
# Age                       0
# Annual Income (k$)        0
# Spending Score (1-100)    0
# dtype: int64

# %% [markdown]
# **No missing values found**

# %% [markdown]
# ###*Remove duplicate rows using .drop_duplicates()*

# %%
df = df.drop_duplicates()

# %%
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    Male   19                  15                      39
# 1             2    Male   21                  15                      81
# 2             3  Female   20                  16                       6
# 3             4  Female   23                  16                      77
# 4             5  Female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  Female   35                 120                      79
# 196         197  Female   45                 126                      28
# 197         198    Male   32                 126                      74
# 198         199    Male   32                 137                      18
# 199         200    Male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# **If there were any duplicate cells, all of them were removed/dropped from the dataset**

# %% [markdown]
# ###*Standardize text values like gender, country names, etc.*

# %%
df['Gender'] = df['Gender'].str.strip().str.lower()
df
# Out:
#      CustomerID  Gender  Age  Annual Income (k$)  Spending Score (1-100)
# 0             1    male   19                  15                      39
# 1             2    male   21                  15                      81
# 2             3  female   20                  16                       6
# 3             4  female   23                  16                      77
# 4             5  female   31                  17                      40
# ..          ...     ...  ...                 ...                     ...
# 195         196  female   35                 120                      79
# 196         197  female   45                 126                      28
# 197         198    male   32                 126                      74
# 198         199    male   32                 137                      18
# 199         200    male   30                 137                      83
#
# [200 rows x 5 columns]

# %% [markdown]
# **I have used .strip() to remove all the whitespaces and then use .lower() to convert entire string into lowercase**

# %% [markdown]
# ###*Convert date formats to a consistent type (e.g., dd-mm-yyyy).*

# %% [markdown]
# **Since there is no date attribute, I will skip this.**

# %% [markdown]
# ###*Rename column headers to be clean and uniform (e.g., lowercase, no spaces).*

# %%
df.columns = df.columns.str.strip().str.lower().str.replace(r'[^a-z0-9]+', '_', regex=True)

# %%
df
# Out:
#      customerid  gender  age  annual_income_k_  spending_score_1_100_
# 0             1    male   19                15                     39
# 1             2    male   21                15                     81
# 2             3  female   20                16                      6
# 3             4  female   23                16                     77
# 4             5  female   31                17                     40
# ..          ...     ...  ...               ...                    ...
# 195         196  female   35               120                     79
# 196         197  female   45               126                     28
# 197         198    male   32               126                     74
# 198         199    male   32               137                     18
# 199         200    male   30               137                     83
#
# [200 rows x 5 columns]

# %% [markdown]
# ###*Cleaned Dataset*

# %%
df
# Out:
#      customerid  gender  age  annual_income_k_  spending_score_1_100_
# 0             1    male   19                15                     39
# 1             2    male   21                15                     81
# 2             3  female   20                16                      6
# 3             4  female   23                16                     77
# 4             5  female   31                17                     40
# ..          ...     ...  ...               ...                    ...
# 195         196  female   35               120                     79
# 196         197  female   45               126                     28
# 197         198    male   32               126                     74
# 198         199    male   32               137                     18
# 199         200    male   30               137                     83
#
# [200 rows x 5 columns]
